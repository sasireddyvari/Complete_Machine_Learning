# %% [markdown]
# <a href="https://colab.research.google.com/github/sasireddyvari/LifeCycle_DataScience/blob/master/Resume_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 3.9MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61087 sha256=a2de4530474c8decd2752fb2029e0b107362decdd2b7201d974a16d83b3c1dab
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
import PyPDF2

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/ML Assignment test dataset.zip'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/ML Assignment test dataset.zip
#    creating: censored/
#   inflating: censored/.DS_Store
#   inflating: __MACOSX/censored/._.DS_Store
#   inflating: censored/resume_9.pdf
#   inflating: __MACOSX/censored/._resume_9.pdf
#   inflating: censored/resume_8.pdf
#   inflating: __MACOSX/censored/._resume_8.pdf
#   inflating: censored/resume_20.pdf
#   inflating: __MACOSX/censored/._resume_20.pdf
#   inflating: censored/resume_18.pdf
#   inflating: __MACOSX/censored/._resume_18.pdf
#   inflating: censored/resume_19.pdf
#   inflating: __MACOSX/censored/._resume_19.pdf
#   inflating: censored/resume_17.pdf
#   inflating: __MACOSX/censored/._resume_17.pdf
#   inflating: censored/resume_16.pdf
#   inflating: __MACOSX/censored/._resume_16.pdf
#   inflating: censored/resume_14.pdf
#   inflating: __MACOSX/censored/._resume_14.pdf
#   inflating: censored/resume_15.pdf
#   inflating: __MACOSX/censored/._resume_15.pdf
# ...

# %%
path='/content/censored/resume_3.pdf'

# %% [markdown]
# **Converting pdf to text**

# %%
def convert_pdf_to_text_py(file_path):
    content = ""
    with open(file_path, "rb") as f:
        pdfDoc = PyPDF2.PdfFileReader(f,"rb")
        for i in range(0,pdfDoc.getNumPages()):
            content += pdfDoc.getPage(i).extractText() + "\n"
        return (content)

# %%
text=convert_pdf_to_text_py(path)

# %%
text=text.replace('\n','') ## Removed Newline characters
temp=text

# %%
temp
# Out:
# 'As an inquisitive and enthusiastic young mind, I chose to pursue  an education in the ˜eld of engineering after my high school graduation. The knowledge so acquired in the four years of formal education is highly valuable. As I laid down my options for further studies, I thoroughly analyzed where my true interests lie. Hence, I chose to pursue a Master™s in the ˜eld of apparel design. Today, as I learn and progress, I constantly make an effort to understand and explore the endless possibilities of utilizing both the technical and creative knowledge.aishwarya.pammi@gmail.com+91 73378 34067WORK EXPERIENCEEDUCATIONTOOLSSKILLSŁ Ł Ł Ł AISHWARYA 22 Mar 1992Bengaluru, IndiaDOBADOBE INDESIGNADOBE PHOTOSHOP ADOBE ILLUSTRATOR MS OFFICESir. M. Visvesvaraya Institute of Technology, Bengaluru, India.National Institute of Design, Gandhinagar, India.Design Intern for ALIBI, a womens wear brand. Development of vector graphics, prints, silhouettes and tech sheets for Alibi™s Spring Summer 17 collect
# ...

# %%
import re

# %%
def get_info_from_text(text,regex):
    """
    Extract the string that matches the regular expressions
    param:
        text - text string extracted from pdf file
        regex - reguar expressions that is to be searched for
    returns the searched string
    """
    required_info=''
    ResSearch = re.search(regex, text)
    if ResSearch:
      required_info = ResSearch.group(1)
    return required_info

# %%
import re 
import string 
import nltk 
import spacy 
import pandas as pd 
import numpy as np 
import math 
from tqdm import tqdm 

from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy import displacy 

pd.set_option('display.max_colwidth', 200)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc=nlp(temp)

# %%
# print token, dependency, POS tag 
for tok in doc: 
  print(tok.text, "-->",tok.dep_,"-->", tok.pos_)
# Out:
# As --> prep --> SCONJ
# an --> det --> DET
# inquisitive --> amod --> ADJ
# and --> cc --> CCONJ
# enthusiastic --> conj --> ADJ
# young --> amod --> ADJ
# mind --> pobj --> NOUN
# , --> punct --> PUNCT
# I --> nsubj --> PRON
# chose --> ROOT --> VERB
# to --> aux --> PART
# pursue --> xcomp --> VERB
#   -->  --> SPACE
# an --> det --> DET
# education --> dobj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# ˜eld --> pobj --> NOUN
# of --> prep --> ADP
# engineering --> pobj --> NOUN
# after --> prep --> ADP
# my --> poss --> DET
# high --> amod --> ADJ
# school --> compound --> NOUN
# graduation --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# knowledge --> nsubj --> NOUN
# so --> advmod --> ADV
# acquired --> ROOT --> VERB
# in --> prep --> ADP
# the --> det --> DET
# four --> nummod --> NUM
# years --> pobj --> NOUN
# of --> prep --> ADP
# formal --> amod --> ADJ
# education --> pobj --> NOUN
# is --> conj --> AUX
# highly --> advmod --> ADV
# ...

# %%
docx=nlp(text)

# %%
# print token, dependency, POS tag 
for tok in docx: 
  print(tok.text, "-->",tok.dep_,"-->", tok.pos_)
# Out:
# As --> prep --> SCONJ
# an --> det --> DET
# inquisitive --> amod --> ADJ
# and --> cc --> CCONJ
# enthusiastic --> conj --> ADJ
# young --> amod --> ADJ
# mind --> pobj --> NOUN
# , --> punct --> PUNCT
# I --> nsubj --> PRON
# chose --> ROOT --> VERB
# to --> aux --> PART
# pursue --> xcomp --> VERB
#   -->  --> SPACE
# an --> det --> DET
# education --> dobj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# ˜eld --> pobj --> NOUN
# of --> prep --> ADP
# engineering --> pobj --> NOUN
# after --> prep --> ADP
# my --> poss --> DET
# high --> amod --> ADJ
# school --> compound --> NOUN
# graduation --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# knowledge --> nsubj --> NOUN
# so --> advmod --> ADV
# acquired --> ROOT --> VERB
# in --> prep --> ADP
# the --> det --> DET
# four --> nummod --> NUM
# years --> pobj --> NOUN
# of --> prep --> ADP
# formal --> amod --> ADJ
# education --> pobj --> NOUN
# is --> conj --> AUX
# highly --> advmod --> ADV
# ...

# %%
#define the pattern 
pattern = [{'POS':'NOUN'}, 
           {'LOWER': 'such'}, 
           {'LOWER': 'as'}, 
           {'POS': 'PROPN'} #proper noun
]

# %%
matcher = Matcher(nlp.vocab) 
matcher.add("matching_1", None, pattern) 

matches = matcher(doc) 
span = docx[:]

print(span.text)
# Out:
# As an inquisitive and enthusiastic young mind, I chose to pursue  an education in the ˜eld of engineering after my high school graduation. The knowledge so acquired in the four years of formal education is highly valuable. As I laid down my options for further studies, I thoroughly analyzed where my true interests lie. Hence, I chose to pursue a Master™s in the ˜eld of apparel design. Today, as I learn and progress, I constantly make an effort to understand and explore the endless possibilities of utilizing both the technical and creative knowledge.aishwarya.pammi@gmail.com+91 73378 34067WORK EXPERIENCEEDUCATIONTOOLSSKILLSŁ Ł Ł Ł AISHWARYA 22 Mar 1992Bengaluru, IndiaDOBADOBE INDESIGNADOBE PHOTOSHOP ADOBE ILLUSTRATOR MS OFFICESir. M. Visvesvaraya Institute of Technology, Bengaluru, India.National Institute of Design, Gandhinagar, India.Design Intern for ALIBI, a womens wear brand. Development of vector graphics, prints, silhouettes and tech sheets for Alibi™s Spring Summer 17 collecti
# ...

# %%
for tok in docx: 
  print(tok.text, "-->",tok.dep_, "-->",tok.pos_)
# Out:
# As --> prep --> SCONJ
# an --> det --> DET
# inquisitive --> amod --> ADJ
# and --> cc --> CCONJ
# enthusiastic --> conj --> ADJ
# young --> amod --> ADJ
# mind --> pobj --> NOUN
# , --> punct --> PUNCT
# I --> nsubj --> PRON
# chose --> ROOT --> VERB
# to --> aux --> PART
# pursue --> xcomp --> VERB
#   -->  --> SPACE
# an --> det --> DET
# education --> dobj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# ˜eld --> pobj --> NOUN
# of --> prep --> ADP
# engineering --> pobj --> NOUN
# after --> prep --> ADP
# my --> poss --> DET
# high --> amod --> ADJ
# school --> compound --> NOUN
# graduation --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# knowledge --> nsubj --> NOUN
# so --> advmod --> ADV
# acquired --> ROOT --> VERB
# in --> prep --> ADP
# the --> det --> DET
# four --> nummod --> NUM
# years --> pobj --> NOUN
# of --> prep --> ADP
# formal --> amod --> ADJ
# education --> pobj --> NOUN
# is --> conj --> AUX
# highly --> advmod --> ADV
# ...

# %%
import pandas as pd 
  
# import the StrinIO function 
# from io module 
from io import StringIO 
df = pd.read_csv(StringIO(temp), sep =",") 
print(df)
# Out:
# Empty DataFrame
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# ˜eld 86 90 LOC
# the four years 168 182 DATE
# Today 388 393 DATE
# 22 648 650 CARDINAL
# 1992Bengaluru 655 668 CARDINAL
# PHOTOSHOP ADOBE ILLUSTRATOR 698 725 ORG
# M. Visvesvaraya Institute of Technology 740 779 ORG
# Bengaluru 781 790 GPE
# India 792 797 GPE
# National Institute of Design 798 826 ORG
# Gandhinagar 828 839 GPE
# India 841 846 GPE
# ALIBI 865 870 ORG
# Alibi 965 970 ORG
# Spring Summer 17 973 989 EVENT
# INMARK 1001 1007 ORG
# Bengaluru 1030 1039 GPE
# India 1041 1046 GPE
# the Centre of Design & Technology 1066 1099 ORG
# Smart Function Materials 1106 1130 ORG
# SAXION University of Applied Sciences 1216 1253 ORG
# Enschede 1254 1262 GPE
# Netherlands 1264 1275 GPE
# US 1294 1296 GPE
# ARVIND LTD 1489 1499 ORG
# Bengaluru 1501 1510 ORG
# India.2015 1512 1522 ORG
# 16 - Feb 17 1686 1697 DATE

# %%
path='/content/censored/resume_7.pdf'

# %%
def convert_pdf_to_text_py(file_path):
    content = ""
    with open(file_path, "rb") as f:
        pdfDoc = PyPDF2.PdfFileReader(f,"rb")
        for i in range(0,pdfDoc.getNumPages()):
            content += pdfDoc.getPage(i).extractText() + "\n"
        return (content)

# %%
text=convert_pdf_to_text_py(path)
text=text.replace('\n','')
text
# Out:
# 'cvBHAWNA SAPRA1362-A Maruti ViharMG Road, Gurgaon9896231244/Sheyasapra5/sheyasapraEDUCATIONWORK EXPERIENCE(2014-2015)DELHI PUBLIC SCHOOL, PANIPAT12TH- NON-MEDICALDELHI PUBLIC SCHOOL PANIPAT(2015-2018)KURUKSHETRA UNIVERSITY,KURUKSHETRA B.SC GRAPHIC & ANIMATIONINSTITUTE OF MASS COMMUNICATION & MEDIA(JUNE 2017-AUGUST 2017)DIGIT BAZARGRAPHIC DESIGNER (INTERN)job- Social media post designing, logo, banner(SEPT 2017- PRESENT)METTlGRAPHIC DESIGNER (INTERN)job- Social media post designing, logo, banner, illustration, UI UX(2107-Present)FREELANCINGLANGUAGESENGLISHHINDISKILLSADOBE ILLUSRTRATORADOBE PHOTOSHOPADOBE AFTER EFFECTCORAL DRAW'

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# cvBHAWNA SAPRA1362-A Maruti ViharMG Road, 0 41 PERSON
# PANIPAT12TH- 138 150 CARDINAL
# NON-MEDICALDELHI PUBLIC SCHOOL PANIPAT(2015-2018)KURUKSHETRA UNIVERSITY 151 222 ORG
# KURUKSHETRA B.SC GRAPHIC & ANIMATIONINSTITUTE 223 268 ORG
# 2017)DIGIT 316 326 CARDINAL
